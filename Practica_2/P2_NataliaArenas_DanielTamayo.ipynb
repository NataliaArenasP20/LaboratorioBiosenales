# %% [markdown]
# # **#Práctica 1**
# ### Natalia Arenas Pachón - 1007729698
# ### Daniel Tamayo - 1214747121

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Secuencias discretas elementales**
#
# Impulso unitario

# %%
def impseq(n0,n1,n2):
  #Genera x(n) = delta(n-n0); n1<= n >= n2
  n = np.arange(n1,n2+1) #Se crea el vector de muestras
  x = (n-n0)==0
  return[x,n]

x,n=impseq(5,-10,10)
plt.stem(n,x)
plt.xlabel('$n$')
plt.title('Impulso Unitario')
plt.ylabel('$\delta[n]$')
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\tamay\AppData\Local\Temp\ipykernel_8024\3789270689.py:11: SyntaxWarning: invalid escape sequence '\d'
#   plt.ylabel('$\delta[n]$')
# Text(0, 0.5, '$\\delta[n]$')

# %% [markdown]
# **Punto 1**
#
# Escalón unitario

# %%
def escaseq(n0,n1,n2):  
  n = np.arange(n1,n2+1) #Se crea el vector de muestras
  x = (n-n0)>=0
  return[x,n]

x,n=escaseq(0,-10,10)
plt.stem(n,x)
plt.xlabel('$n$')
plt.title('Escalon Unitario')
plt.ylabel('$\mu [n]$')
# Out:
# Text(0, 0.5, '$\\mu [n]$')

# %% [markdown]
# **Punto #2**
#
# Rampa

# %%
def ramseq(n0,n1,n2):  
  n = np.arange(n1,n2+1) #Se crea el vector de muestras
  x = n*((n-n0)>=0)
  return[x,n]

x,n=ramseq(0,-5,15)
plt.stem(n,x)
plt.xlabel('$n$')
plt.title('Rampa Discreta')
plt.ylabel('$r[n]$')
# Out:
# Text(0, 0.5, '$r[n]$')

# %% [markdown]
# Exponenciales complejas

# %%
def exponcencial(n0,n1,n2,img):  
  n = np.arange(n1,n2+1) #Se crea el vector de muestras
  u = (n-n0) >= 0  # Escalón unitario
  #x = np.e**(n-n0) * u
  x = np.exp(img*n) * u
  
  return[x,n]

I = 1 + 1j
x,n=exponcencial(5,0,20,I)
plt.stem(n,x)
plt.xlabel('$n$')
plt.title('Exponencial')
plt.ylabel('X[n]')
# Out:
# Text(0, 0.5, 'X[n]')

# %% [markdown]
# Sinusoides

# %%
def Sinusoides(n0,n1,n2,theta,omega):  
  n = np.arange(n1,n2+1) #Se crea el vector de muestras
  u = (n-n0) >= 0  # Escalón unitario
  x = np.sin(theta*omega*n)*u 
  
  return[x,n]

x,n=Sinusoides(5,0,20,10,10)
plt.stem(n,x)
plt.xlabel('$n$')
plt.title('Señal Sinusoidal')
plt.ylabel('X[n]')
# Out:
# Text(0, 0.5, 'X[n]')
